# %%
import matplotlib

# %%
print(matplotlib.__version__)
# Out:
# 3.10.0

# %%
import matplotlib.pyplot as plt
import numpy as np

#Draw a line in a diagram from position (0,0) to position (6,250):
xpoint = np.array([0,6])
ypoint = np.array([0,250])

plt.plot(xpoint,ypoint)
plt.show()

# %% [markdown]
# The plot() function is used to draw points (markers) in a diagram.
#
# By default, the plot() function draws a line from point to point.
#
# The function takes parameters for specifying points in the diagram.
#
# Parameter 1 is an array containing the points on the x-axis.
#
# Parameter 2 is an array containing the points on the y-axis.
#
# If we need to plot a line from (1, 3) to (8, 10), we have to pass two arrays [1, 8] and [3, 10] to the plot function.

# %%
#Draw two points in the diagram, one at position (1, 3) and one in position (8, 10):

xpoint = np.array([1,3])
ypoint = np.array([8,10])
plt.plot(xpoint,ypoint,'o')
plt.show()

# %%
xpoint = np.array([1, 2, 6, 8])
ypoint = np.array([3, 8, 1, 10])
plt.plot(ypoint,marker='o')
plt.show()

# %%
xpoint = np.array([1, 2, 6, 8])
ypoint = np.array([3, 8, 1, 10])
plt.plot(xpoint,ypoint,marker='_')
plt.show()

# %%
xpoint = np.array([1, 2, 6, 8])
ypoint = np.array([3, 8, 1, 10])
plt.plot(ypoint,'o-.c') # here marker|line|color will do the job, o means ring, -. means type of line need to make, c means cyan color
plt.show()

# %%
xpoint = np.array([1, 2, 6, 8])
ypoint = np.array([3, 8, 1, 10])
plt.plot(ypoint,'o-.c',ms=100) # here ms means marker size
plt.show()

# %%
xpoint = np.array([1, 2, 6, 8])
ypoint = np.array([3, 8, 1, 10])
plt.grid()
plt.plot(ypoint,'o-.c', ms=8,mec='b') # here mec means marker edge color

plt.show()

# %% [markdown]
# Labels

# %%
xpoint = np.array([1,8,3,5])
ypoint = np.array([2,3,5,7])
plt.xlabel('Mihir')
plt.ylabel('Mihir')
plt.title('Mihir vyas')
plt.plot(xpoint,ypoint)
plt.show()

# %% [markdown]
# Grid

# %%
xpoint = np.array([1,8,3,5])
ypoint = np.array([2,4,6,9])
plt.grid()
plt.plot(xpoint,ypoint)
plt.show()

# %%
xpoint = np.array([1,8,3,5])
ypoint = np.array([2,4,6,9])
plt.grid(axis='x')
plt.plot(xpoint,ypoint)
plt.show()

# %%
xpoint = np.array([1,8,3,5])
ypoint = np.array([2,4,6,9])
plt.grid(axis='y')
plt.plot(xpoint,ypoint,'o:')
plt.show()

# %%
xpoint = np.array([1,8,3,5])
ypoint = np.array([2,4,6,9])
plt.grid(axis='y',color='green',linestyle='--',linewidth=0.5)
plt.plot(xpoint,ypoint,'o:')
plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# Scatter

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.plot(x, y,'o')
plt.show()

# %%
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# Bar

# %%
x = np.array(['a','b','c','d'])
y = np.array([1,2,3,4])
plt.barh(x,y)
plt.grid()
plt.show()

# %% [markdown]
# Histograms

# %%
x = np.random.normal(170, 10, 250)
plt.hist(x)
plt.show()

# %% [markdown]
# Pie

# %%
x = np.array([4,3,2,1])
mylabels = ['Apple','Banana','Cherries','Dates']
plt.pie(x,labels=mylabels)
plt.show()

# %%
x = np.array([4,3,2,1])
mylabels = ['Apple','Banana','Cherries','Dates']
plt.pie(x,labels=mylabels,startangle=80)
plt.show()

# %%
x = np.array([4,3,2,1])
mylabels = ['Apple','Banana','Cherries','Dates']
myexplode = [0.2,1,0,0.05]
plt.pie(x,labels=mylabels,startangle=80,explode=myexplode)
plt.show()

# %%
x = np.array([4,3,2,1])
mylabels = ['Apple','Banana','Cherries','Dates']
plt.pie(x,labels=mylabels,startangle=80)
plt.legend(title='Fruits')
plt.show()
